# %%
import pandas as pd
import numpy as np
data=pd.read_csv('/home/AIML_Student/Desktop/2030B/hepatitis_csv.csv')
data
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
#Q1_2
#count number of null values in each column
nullCount=data.isna().sum()
nullCount
# Out:
# age                 0
# sex                 0
# steroid             1
# antivirals          0
# fatigue             1
# malaise             1
# anorexia            1
# liver_big          10
# liver_firm         11
# spleen_palpable     5
# spiders             5
# ascites             5
# varices             5
# bilirubin           6
# alk_phosphate      29
# sgot                4
# albumin            16
# protime            67
# histology           0
# class               0
# dtype: int64

# %%
#protime has 67 NaN/Null values out of 155 rows. so drop the column
data.drop(['protime'],axis=1,inplace=True)
data
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 3     31  female     NaN        True   False   False    False      True
# 4     34  female    True       False   False   False    False      True
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 150   46  female    True       False    True    True     True      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
#Q1_3
#deleting rows with null values
data.dropna(inplace=True)
data
# Out:
#      age     sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0     30    male   False       False   False   False    False     False
# 1     50  female   False       False    True   False    False     False
# 2     78  female    True       False    True   False    False      True
# 5     34  female    True       False   False   False    False      True
# 10    39  female   False        True   False   False    False     False
# ..   ...     ...     ...         ...     ...     ...      ...       ...
# 149   36  female    True       False   False   False    False      True
# 151   44  female    True       False    True   False    False      True
# 152   61  female   False       False    True    True    False     False
# 153   53    male   False       False    True   False    False      True
# 154   43  female    True       False    True   False    False      True
#
#     liver_firm spleen_palpable spiders ascites varices  bilirubin  \
# ...

# %%
#check if there are any null values
nullCount=data.isna().sum()
nullCount
# Out:
# age                0
# sex                0
# steroid            0
# antivirals         0
# fatigue            0
# malaise            0
# anorexia           0
# liver_big          0
# liver_firm         0
# spleen_palpable    0
# spiders            0
# ascites            0
# varices            0
# bilirubin          0
# alk_phosphate      0
# sgot               0
# albumin            0
# histology          0
# class              0
# dtype: int64

# %%
#Q1_4
dummy=pd.get_dummies(data['sex'])
dummy
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 5         1     0
# 10        1     0
# ..      ...   ...
# 149       1     0
# 151       1     0
# 152       1     0
# 153       0     1
# 154       1     0
#
# [112 rows x 2 columns]

# %%
#data=pd.concat([data,dummy],axis=1)
#data.drop(['sex'],axis=1,inplace=True)
#data

# %%
#Q1_5
#check if there are any missing values in the data
data.isnull().values.any()
# Out:
# False

# %%
#Q1_6
#convert dataframe into numpy 
array=data.to_numpy()
array
# Out:
# array([[30, 'male', False, ..., 4.0, False, 'live'],
#        [50, 'female', False, ..., 3.5, False, 'live'],
#        [78, 'female', True, ..., 4.0, False, 'live'],
#        ...,
#        [61, 'female', False, ..., 4.1, True, 'live'],
#        [53, 'male', False, ..., 4.1, True, 'live'],
#        [43, 'female', True, ..., 3.1, True, 'die']], dtype=object)

# %%
data.replace('live',1,inplace=True)
data.replace('female',1,inplace=True)
data.replace('male',0,inplace=True)

# %%
data.replace('die',0,inplace=True)
data
# Out:
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    0    False       False    False    False     False      False
# 1     50    1    False       False     True    False     False      False
# 2     78    1     True       False     True    False     False       True
# 5     34    1     True       False    False    False     False       True
# 10    39    1    False        True    False    False     False      False
# ..   ...  ...      ...         ...      ...      ...       ...        ...
# 149   36    1     True       False    False    False     False       True
# 151   44    1     True       False     True    False     False       True
# 152   61    1    False       False     True     True     False      False
# 153   53    0    False       False     True    False     False       True
# 154   43    1     True       False     True    False     False       True
#
#      liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x = data.iloc[:, :-1]
y = data.iloc[:, -1]
#X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.05, random_state=0)

# %%
x
# Out:
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    0    False       False    False    False     False      False
# 1     50    1    False       False     True    False     False      False
# 2     78    1     True       False     True    False     False       True
# 5     34    1     True       False    False    False     False       True
# 10    39    1    False        True    False    False     False      False
# ..   ...  ...      ...         ...      ...      ...       ...        ...
# 149   36    1     True       False    False    False     False       True
# 151   44    1     True       False     True    False     False       True
# 152   61    1    False       False     True     True     False      False
# 153   53    0    False       False     True    False     False       True
# 154   43    1     True       False     True    False     False       True
#
#      liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 5      1
# 10     1
#       ..
# 149    1
# 151    1
# 152    1
# 153    1
# 154    0
# Name: class, Length: 112, dtype: int64

# %%
x_train = np.array(X_train).reshape((-1, 1))
x_train
# Out:
# array([[34],
#        ['male'],
#        [True],
#        ...,
#        [78.0],
#        [4.2],
#        [False]], dtype=object)

# %%
y_train
# Out:
# 125    1
# 2      1
# 124    1
# 42     1
# 29     1
#       ..
# 151    1
# 88     0
# 84     1
# 60     1
# 54     1
# Name: class, Length: 106, dtype: int64

# %%
model=LinearRegression().fit(x,y)

# %%
r_sq = model.score(x,y)
r_sq
# Out:
# 0.43348840987478354

# %%
#b0:
model.intercept_
# Out:
# 0.8879190694647244

# %%
#b1:
model.coef_
# Out:
# array([ 0.00052578, -0.12620981,  0.00643225, -0.06802469, -0.00126013,
#        -0.10116039,  0.22595991, -0.09143071, -0.00385185, -0.04879398,
#        -0.18470591, -0.22322997, -0.0753846 , -0.08429323,  0.00027808,
#         0.00057763,  0.07684772, -0.08427579])

# %%
y_pred=model.predict(x)
y_pred
# Out:
# array([ 1.16082422,  1.04164251,  1.01002715,  0.96870551,  0.97790611,
#         0.79597413,  0.90615577,  0.97751079,  0.71627071,  0.99842422,
#         1.05614094,  0.90748392,  1.00920683,  1.01699993,  0.97604153,
#         0.95129699,  1.03718969,  1.06124705,  0.85962946,  0.84812254,
#         0.81350991,  1.00724112,  0.85104741,  0.74910376,  1.25836466,
#         1.11047342,  1.01770522,  0.81718817,  1.10963582,  0.9714448 ,
#         0.94718257,  0.34184768,  0.93060592,  1.01267704,  1.00772792,
#         0.95225441,  0.81107711,  1.10895901,  0.9447911 ,  0.90356042,
#         0.98060572,  0.95550327,  1.10174479,  0.82359373,  1.01393867,
#         0.90157058,  0.91784287,  1.02370707,  1.00725397,  0.61421957,
#         0.9782349 ,  0.85506636,  0.90756307,  0.93717302,  0.7986483 ,
#         0.99767028,  1.06942421,  0.78872863,  0.83126253,  1.02150895,
#         0.89019749,  1.05052453,  1.10602505,  0.98015207,  0.86398568,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(data['age'],data['class'],c='y')
plt.show()

# %%
plt.plot(data['age'],y_pred,c='g')
plt.show()
